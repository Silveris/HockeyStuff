# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "data/clean_hockey_data.csv"
nhl_df = pd.read_csv(file)

# %%
nhl_df.head()
# Out:
#    Unnamed: 0  Rk             Player         ID  Age Pos   Tm    GP   G   A  \
# 0           0   1     Connor McDavid  mcdavco01   20   C  EDM  82.0  30  70
# 1           1   2      Sidney Crosby  crosbsi01   29   C  PIT  75.0  44  45
# 2           2   3       Patrick Kane   kanepa01   28  RW  CHI  82.0  34  55
# 3           3   4  Nicklas Backstrom  backsni02   29   C  WSH  82.0  23  63
# 4           4   5    Nikita Kucherov  kucheni01   23  RW  TBL  74.0  40  45
#
#    ...    FOL  FO_percent  HART  Votes  Season   G/60min   A/60min  PTS/60min  \
# 0  ...  458.0        43.2     1   1604    2017  1.038661  2.423543   3.462204
# 1  ...  906.0        48.2     0   1104    2017  1.770624  1.810865   3.581489
# 2  ...   44.0        13.7     0    206    2017  1.163056  1.881414   3.044470
# 3  ...  648.0        51.4     0     60    2017  0.921844  2.525050   3.446894
# 4  ...    0.0         0.0     0    119    2017  1.668985  1.877608   3.546592
#
#    HIT/60min  BLK/60min
# 0   1.177149   1.004039
# 1   3.219316   1.086519
# 2   0.957811   0.513113
# 3   1.803607   1.322645
# 4   1.251739   0.834492
#
# [5 rows x 38 columns]

# %%
# Pass in a df and a category, and the function will produce a new df grouped by the category and showing 
# the average (or mean) of each category
def groupby_avg(df, category):
    temp_df = df.groupby([category])

    avg_goals = temp_df["G/60min"].mean()
    avg_assists = temp_df["A/60min"].mean()
    avg_pts = temp_df["PTS/60min"].mean()
    avg_hits = temp_df["HIT/60min"].mean()
    avg_blocks = temp_df["BLK/60min"].mean()
    avg_shootperc = temp_df["S_percent"].mean()
    count = temp_df["Player"].count()

    new_df = pd.DataFrame({
        "Avg G/60min" : avg_goals,
        "Avg A/60min" : avg_assists,
        "Avg PTS/60min" : avg_pts,
        "Avg HIT/60min" : avg_hits,
        "Avg BLK/60min" : avg_blocks,
        "Avg S_percent" : avg_shootperc,
        "Num Players" : count
    })
    return new_df


def groupby_median(df, category):
    temp_df = df.groupby([category])

    med_goals = temp_df["G/60min"].median()
    med_assists = temp_df["A/60min"].median()
    med_pts = temp_df["PTS/60min"].median()
    med_hits = temp_df["HIT/60min"].median()
    med_blocks = temp_df["BLK/60min"].median()
    med_shhotperc = temp_df["S_percent"].median()
    count = temp_df["Player"].count()


    new_df = pd.DataFrame({
        "Med G/60min" : med_goals,
        "Med A/60min" : med_assists,
        "Med PTS/60min" : med_pts,
        "Med HIT/60min" : med_hits,
        "Med BLK/60min" : med_blocks,
        "Num Players" : count
    })
    return new_df

# %%
# Data split by position
forwards_data = nhl_df[(nhl_df["Pos"] != "D") & (nhl_df["Age"] >= 20)]
defensemen_data = nhl_df[(nhl_df["Pos"] == "D") & (nhl_df["Age"] >= 20)]

# Data for only younger players. Exlcuding 18/19 yr olds because of how few there are and their tendency to be superstars
young_df = forwards_data[(forwards_data["Age"] <= 22) & (forwards_data["Age"] >= 20)]

#
ssn18_df = forwards_data[forwards_data["Season"] == 2018]
ssn04_df = forwards_data[forwards_data["Season"] == 24]

# %%
youth_by_season_df = groupby_avg(young_df, "Season")
youth_by_season_df.plot(kind="line", y = "Avg PTS/60min")
plt.title("Age 20-22")
# Out:
# Text(0.5, 1.0, 'Age 20-22')

# %%
age_groupings_df = groupby_avg(forwards_data, "Age")
age_groupings_df.plot(kind="line", y = "Avg PTS/60min")
plt.title("Forwards")
# Out:
# Text(0.5, 1.0, 'Forwards')

# %%
d_age_groupings_df = groupby_avg(defensemen_data, "Age")
d_age_groupings_df.plot(kind="line", y = "Avg PTS/60min")
plt.title("Defensemen")
# Out:
# Text(0.5, 1.0, 'Defensemen')

# %%
temp_df = forwards_data.groupby(["Age", "Season"])

avg_goals = temp_df["G/60min"].mean()
avg_assists = temp_df["A/60min"].mean()
avg_pts = temp_df["PTS/60min"].mean()
avg_hits = temp_df["HIT/60min"].mean()
avg_blocks = temp_df["BLK/60min"].mean()
count = temp_df["Age"].count()

age_group_df = pd.DataFrame({
    "Avg G/60min" : avg_goals,
    "Avg A/60min" : avg_assists,
    "Avg PTS/60min" : avg_pts,
    "Avg HIT/60min" : avg_hits,
    "Avg BLK/60min" : avg_blocks,
    "Num Players" : count
})

age_group_df.head(25)
# Out:
#             Avg G/60min  Avg A/60min  Avg PTS/60min  Avg HIT/60min  \
# Age Season
# 20  2004       0.710083     1.000822       1.710905       0.000000
#     2006       0.969825     1.220506       2.190331       0.000000
#     2007       1.136053     1.441294       2.577347       0.000000
#     2008       0.807087     1.282267       2.089355       4.021606
#     2009       0.870885     1.195815       2.066700       3.767359
#     2010       0.899800     1.105585       2.005386       3.585116
#     2011       0.884762     1.150141       2.034903       3.348614
#     2012       0.787953     0.968895       1.756848       4.333842
#     2013       0.716108     0.959380       1.675488       3.930470
#     2014       0.791017     0.966683       1.757700       5.408609
#     2015       0.686432     1.094831       1.781263       5.747016
#     2016       0.794921     1.104008       1.898929       3.414201
#     2017       0.811917     1.089265       1.901181       3.255384
#     2018       1.104138     1.371059       2.475197       3.168182
# 21  2004       0.628754     0.764130       1.392884       0.000000
#     2006       0.820643     0.966650       1.787293       0.000000
#     2007       0.803853     1.109560       1.913413       0.000000
#     2008       0.771077     1.052324       1.823401       6.846588
#     2009       0.877868     1.143925       2.021793       2.872837
#     2010       0.724978     1.003993       1.728971       4.824210
#     2011       0.812687     1.058452       1.871139       4.830588
#     2012       0.664731     0.995876       1.660607       5.665691
#     2013       0.707039     1.017120       1.724159       5.365717
#     2014       0.783985     1.039861       1.823846       4.989238
#     2015       0.779479     1.069155       1.848635       6.305050
#
#             Avg BLK/60min  Num Players
# Age Season
# 20  2004         0.000000           13
#     2006         0.000000           12
#     2007         0.000000            4
#     2008         1.480588           12
#     2009         1.169460           19
#     2010         1.573517            9
#     2011         1.151165           10
#     2012         1.501521           12
#     2013         1.767673           11
#     2014         1.769540           11
#     2015         1.827784           11
#     2016         1.517629           13
#     2017         1.426469           17
#     2018         1.481148           12
# 21  2004         0.000000           15
#     2006         0.000000           18
#     2007         0.000000           22
#     2008         1.615761           14
#     2009         0.655232           41
#     2010         1.500510           19
#     2011         1.682044           18
#     2012         1.778677           22
#     2013         1.672429           22
#     2014         1.882568           20
#     2015         1.807928           21

# %%
age_group_df.unstack("Season").plot(kind="line", y = "Avg PTS/60min")

# %%
season_split_df = forwards_data[(forwards_data["Season"] == 2004) | (forwards_data["Season"] == 2011) | (forwards_data["Season"] == 2018)]
temp_df = season_split_df.groupby(["Age", "Season"])

med_goals = temp_df["G/60min"].median()
med_assists = temp_df["A/60min"].median()
med_pts = temp_df["PTS/60min"].median()
med_hits = temp_df["HIT/60min"].median()
med_blocks = temp_df["BLK/60min"].median()
count = temp_df["Age"].count()

new_df = pd.DataFrame({
    "Med G/60min" : med_goals,
    "Med A/60min" : med_assists,
    "Med PTS/60min" : med_pts,
    "Med HIT/60min" : med_hits,
    "Med BLK/60min" : med_blocks,
    "Num Players" : count
})

new_df.head(25)
# Out:
#             Med G/60min  Med A/60min  Med PTS/60min  Med HIT/60min  \
# Age Season
# 20  2004       0.720000     1.027668       1.962825       0.000000
#     2011       0.833618     1.167733       1.908077       2.515764
#     2018       1.207578     1.232467       2.538205       3.440886
# 21  2004       0.614035     0.873786       1.404959       0.000000
#     2011       0.811137     1.034299       2.010352       2.997829
#     2018       0.911205     1.225816       2.057419       2.972283
# 22  2004       0.737327     0.921659       1.827731       0.000000
#     2011       0.735786     0.993377       1.828388       4.682274
#     2018       0.689655     1.017964       1.935484       3.096774
# 23  2004       0.707756     0.921704       1.765237       0.000000
#     2011       0.755819     1.036384       2.026565       4.093085
#     2018       0.664226     0.967205       1.571879       4.746859
# 24  2004       0.655738     0.790774       1.538462       0.000000
#     2011       0.793313     1.049462       1.840355       4.718625
#     2018       0.721806     0.930057       1.641208       4.995315
# 25  2004       0.683112     0.853890       1.524249       0.000000
#     2011       0.796216     0.971929       1.761944       5.874609
#     2018       0.831510     0.888889       1.833461       4.075472
# 26  2004       0.639432     0.845070       1.436865       0.000000
#     2011       0.740741     0.782609       1.556351       5.849732
#     2018       0.767824     0.922814       1.633440       5.891337
# 27  2004       0.558511     0.978793       1.561562       0.000000
#     2011       0.731288     0.946057       1.740510       4.339349
#     2018       0.672134     0.750109       1.439112       5.164326
# 28  2004       0.592280     0.760480       1.438383       0.000000
#
#             Med BLK/60min  Num Players
# Age Season
# 20  2004         0.000000           13
#     2011         1.228241           10
#     2018         1.266713           12
# 21  2004         0.000000           15
#     2011         1.348624           18
#     2018         1.562235           28
# 22  2004         0.000000           13
#     2011         1.795775           23
#     2018         1.711322           29
# 23  2004         0.000000           42
#     2011         1.564862           34
#     2018         1.974102           36
# 24  2004         0.000000           25
#     2011         1.720005           36
#     2018         1.928420           42
# 25  2004         0.000000           37
#     2011         1.554108           38
#     2018         1.867220           45
# 26  2004         0.000000           39
#     2011         1.896163           45
#     2018         2.498817           42
# 27  2004         0.000000           37
#     2011         1.716303           40
#     2018         2.050026           30
# 28  2004         0.000000           36

# %%
new_df.unstack("Season").plot(kind="line", y = "Med PTS/60min")
